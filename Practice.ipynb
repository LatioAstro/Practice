# %%
# %matplotlib widget
import scipy
import numpy as np
import matplotlib.pyplot as plt
import symengine
from astropy import units as u
from astropy import constants as const
from astropy.visualization import quantity_support
from mpl_toolkits.mplot3d import Axes3D 
import mpl_toolkits.mplot3d as m3d
quantity_support()
# Out:
# <astropy.visualization.units.quantity_support.<locals>.MplQuantityConverter at 0x7ace92fe1e80>

# %%
x2 = lambda x: x**2

# %%
scipy.integrate.quad(x2, 0, 1)
# Out:
# (0.33333333333333337, 3.700743415417189e-15)

# %%
def K_E(m,v):
    if m.unit == None:
        return "m has no units. "
    if v.unit == None:
        return "v has no units. "
    return (m * v**2 / 2).si

# %%
m = 1 * u.kg
v = 5 * u.m / u.ns

# %%
K_E(m, v)
# Out:
# <Quantity 1.25e+19 J>

# %%
testmass = np.linspace(0,100) * u.kg
testmass = 5 * u.kg

# %%
testvelocity = np.linspace(0,100) * u.m / u.s
#testvelocity = 3 * u.m / u.s

# %%
testtime = np.linspace(0,100) * u.s

# %%
testenergy = K_E(testmass, testvelocity)
testenergy
# Out:
# <Quantity [0.00000000e+00, 1.04123282e+01, 4.16493128e+01, 9.37109538e+01,
#            1.66597251e+02, 2.60308205e+02, 3.74843815e+02, 5.10204082e+02,
#            6.66389005e+02, 8.43398584e+02, 1.04123282e+03, 1.25989171e+03,
#            1.49937526e+03, 1.75968347e+03, 2.04081633e+03, 2.34277384e+03,
#            2.66555602e+03, 3.00916285e+03, 3.37359434e+03, 3.75885048e+03,
#            4.16493128e+03, 4.59183673e+03, 5.03956685e+03, 5.50812162e+03,
#            5.99750104e+03, 6.50770512e+03, 7.03873386e+03, 7.59058726e+03,
#            8.16326531e+03, 8.75676801e+03, 9.37109538e+03, 1.00062474e+04,
#            1.06622241e+04, 1.13390254e+04, 1.20366514e+04, 1.27551020e+04,
#            1.34943773e+04, 1.42544773e+04, 1.50354019e+04, 1.58371512e+04,
#            1.66597251e+04, 1.75031237e+04, 1.83673469e+04, 1.92523948e+04,
#            2.01582674e+04, 2.10849646e+04, 2.20324865e+04, 2.30008330e+04,
#            2.39900042e+04, 2.50000000e+04] J>

# %%
fig,ax = plt.subplots(figsize=(10, 6))
ax.plot(testvelocity,testenergy, label='Kinetic Energy')
ax.set_xlabel('Mass (kg)')
ax.set_ylabel('Energy (J)')
ax.legend()

# %%
from matplotlib import cm
from matplotlib.ticker import LinearLocator

fig, ax = plt.subplots(subplot_kw={"projection": "3d"})

# Make data.
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')

# Create the mesh in polar coordinates and compute corresponding Z.
r = np.linspace(0, 1.25, 50)
p = np.linspace(0, 2*np.pi, 50)
R, P = np.meshgrid(r, p)
Z = ((R**2 - p)**2)

# Express the mesh in the cartesian system.
X, Y = R*np.cos(P), R*np.sin(P)

# Plot the surface.
ax.plot_surface(X, Y, Z, cmap=plt.cm.YlGnBu_r)

# Tweak the limits and add latex math labels.
#ax.set_zlim(0, 1)
ax.set_xlabel(r'$\phi_\mathrm{real}$')
ax.set_ylabel(r'$\phi_\mathrm{im}$')
ax.set_zlabel(r'$V(\phi)$')

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

# Define the 3D grid
x = np.linspace(-5, 5, 5)
y = np.linspace(-5, 5, 5)
z = np.linspace(-1, 1, 5)
X, Y, Z = np.meshgrid(x, y, z)

# Define the vector components (e.g., a simple field)
U = X
V = Y
W = Z

# Create the 3D plot
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(111, projection='3d')
ax.quiver(X, Y, Z, U, V, W, length=0.2, normalize=True) # 'length' and 'normalize' adjust arrow appearance

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Vector Field Example')

# Make data.
X = np.arange(-5, 5, 0.1)
Y = np.arange(-5, 5, 0.1)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
# A StrMethodFormatter is used automatically
ax.zaxis.set_major_formatter('{x:.02f}')

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
from numpy import exp,arange
from pylab import meshgrid,cm,imshow,contour,clabel,colorbar,axis,title,show

# the function that I'm going to plot
def z_func(x,y):
 return (1-(x**2+y**3))*exp(-(x**2+y**2)/2)
 
x = arange(-3.0,3.0,0.1)
y = arange(-3.0,3.0,0.1)
X,Y = meshgrid(x, y) # grid of point
Z = z_func(X, Y) # evaluation of the function on the grid

im = imshow(Z,cmap=cm.RdBu) # drawing the function
# adding the Contour lines with labels
cset = contour(Z,arange(-1,1.5,0.2),linewidths=2),#cmap=cm.Set2)
#clabel(cset,inline=True,fmt='%1.1f',fontsize=10)
#colorbar(im) # adding the colobar on the right
# latex fashion title
title('$z=(1-x^2+y^3) e^{-(x^2+y^2)/2}$')
show()

# %%
fig = plt.figure(figsize=(8,6))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z, rstride=4, cstride=4, alpha=0.25)
ax.plot_wireframe(X, Y, Z, rstride=4, cstride=4, lw=0.5,
    color="black", alpha=0.5)
cset = ax.contour(X, Y, Z, zdir='z', offset=-np.pi,
    cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='x', offset=-np.pi,
    cmap=plt.cm.coolwarm)
cset = ax.contour(X, Y, Z, zdir='y', offset=3*np.pi,
    cmap=plt.cm.coolwarm)

ax.set_xlim3d(-np.pi, 2*np.pi)
ax.set_ylim3d(0, 3*np.pi)
ax.set_zlim3d(-np.pi, 2*np.pi)
# Out:
# (-3.141592653589793, 6.283185307179586)

# %%
# Define the 2D function
def z_func1(x, y):
    return x * np.sin(x) - y
def z_func2(x, y):
    return x - y**2

# Create a grid of x and y values
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)

# Evaluate the function on the grid
Z1 = z_func1(X, Y)
Z2 = z_func2(X, Y)


from matplotlib.patches import Polygon
fig, ax = plt.subplots(figsize=(8, 6))
vertices = np.array([ [0,0], [1,1], [2,0] ])
Triangle = Polygon(vertices, closed=True, fill=None, edgecolor='r')
ax.add_patch(Triangle)

# Create the contour plot
contour_plot_1 = ax.contour(X, Y, Z1, levels=0, cmap='Reds')
contour_plot_2 = ax.contour(X, Y, Z2, levels=0, cmap='Blues')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Area enclosed by the curves')
ax.grid(True)


plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure(figsize=(8,8))

ax = fig.add_subplot(1,1,1, projection='3d')

ax.plot_surface(X, Y, Z1, alpha=0.25)
ax.plot_wireframe(X, Y, Z1, color='b',alpha = 0.1)
ax.plot_surface(X, Y, Z2, alpha=0.25)
ax.plot_wireframe(X, Y, Z2, color='r',alpha = 0.1)

vertices = np.array([ [0,0,0], [2,2,0], [4,0,0]])
Triangle = m3d.art3d.Poly3DCollection([vertices], closed=True, edgecolor='r')
ax.add_collection(Triangle)
ax.set_zlim(0,5)
# Out:
# (0.0, 5.0)
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Create sample 3D data
x = np.linspace(-5, 5, 100)
y = np.linspace(-5, 5, 100)
X, Y = np.meshgrid(x, y)
Z = np.sin(np.sqrt(X**2 + Y**2))

# Define the 2D circular clipping region
center_x, center_y = 0, 0
radius = 3

# Create a mask for points outside the circle
mask = (X - center_x)**2 + (Y - center_y)**2 > radius**2

# Apply the mask to the Z data
Z_clipped = np.copy(Z)
Z_clipped[mask] = np.nan

# Plotting
fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z_clipped, cmap='viridis')

ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
ax.set_title('3D Plot Clipped by 2D Circle')

plt.show()

# %%
fig    = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111, projection='3d')

x      = np.linspace(0, 1, 100)
X, Y   = np.meshgrid(x, x)
levels = np.linspace(-0.1, 0.4, 100)  #(z_min,z_max,number of contour),

a = 0
b = 1
c = 2
Z1 = a + .3 * np.sin(2 * X) * np.sin(4 * Y)
Z2 = b + .3 * np.sin(3 * X) * np.sin(4 * Y)
Z3 = c + .3 * np.sin(4 * X) * np.sin(5 * Y)

mask_cond = (X - .5) ** 2 + (Y - .5) ** 2 > .25
Z1 = np.ma.masked_where(mask_cond, Z1)
Z2 = np.ma.masked_where(mask_cond, Z2)
Z3 = np.ma.masked_where(mask_cond, Z3)

plt.contourf(X, Y, Z1, levels=a + levels, cmap='grey_r')
plt.contourf(X, Y, Z2, levels=b + levels, cmap='grey_r')
plt.contourf(X, Y, Z3, levels=c + levels, cmap='grey_r')

ax.set_xlim3d(0, 1)
ax.set_ylim3d(0, 1)
ax.set_zlim3d(0, 3)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
