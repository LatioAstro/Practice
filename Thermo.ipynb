# %%
# %matplotlib widget
import scipy
import numpy as np
import matplotlib.pyplot as plt
import symengine
from astropy import units as u
from astropy import constants as const
import pandas as pd
from astropy.units import Quantity
from astropy.visualization import quantity_support
from mpl_toolkits.mplot3d import Axes3D 
import mpl_toolkits.mplot3d as m3d
from math import lgamma, log, exp, comb
from SolverFunction import _find_unknown,auto_bracket,solve_quantity, simplify
quantity_support()
# Out:
# <astropy.visualization.units.quantity_support.<locals>.MplQuantityConverter at 0x77f9a8954590>

# %% [markdown]
# ### 3.22. Sketch (or use a computer to plot) a graph of the entropy of a two-state paramagnet as a function of temperature. Describe how this graph would change if you varied the magnetic field strength.

# %%
temp_range = np.linspace(0,100)

def multiplicity_dipole(up,down):
    total = up+down
    

def entropy(omega):
    return const.k_B * np.ln(omega)

# %% [markdown]
# ### 3.28. A liter of air, initially at room temperature and atmospheric pressure, is heated at constant pressure until it doubles in volume. Calculate the increase in its entropy during this process.

# %% [markdown]
# ### 4.1. Recall Problem 1.34, which concerned an ideal diatomic gas taken around a rectangular cycle on a PV diagram. Suppose now that this system is used as a heat engine, to convert the heat added into mechanical work.
#
# #### (a) Evaluate the efficiency of this engine for the case V2 = 3 * V1, P2 = 2 * P1
#
# #### (b) Calculate the efficiency of an "ideal" engine operating between the same temperature extremes.

# %% [markdown]
# ### 4.2. At a power plant that produces 1 GW of electricity, the steam turbines take in steam at a temperature of 500 C, and the waste heat is expelled into the environment at 20 C.
#
# #### (a) What is the maximum possible efficiency of this plant?
#
# #### (b) Suppose you develop a new material for making pipes and turbines, which allows the maximum steam temperature to be raised to 600 C. Roughly how much money can you make in a year by installing your improved hardware, if you sell the additional electricity for 5 cents per kW hr? (Assume the total amount of fuel consumed at the plant is unchanged.)

# %% [markdown]
# ### 4.5. Prove directly (by calculating the heat taken in and the heat expelled) that a Carnot engine using an ideal gas as the working substance has an efficiency 1-Tc/Th.

# %% [markdown]
# ### 4.11. What is the maximum possible COP for a cyclic refrigerator operating between a high-temperature reservoir at 1 K and a low temperature reservoir at 0.01 K?

# %% [markdown]
# ### 4.16. Prove that *if* you had a heat engine whose efficiency was better than the ideal value (4.5), you could hook it up to an ordinary Carnot refrigerator to make a refrigerator that requires no work input.
